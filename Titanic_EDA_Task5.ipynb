# %% [markdown]
# # 🛳 Titanic Dataset - Exploratory Data Analysis (EDA)
# **Internship Task 5**
# Tool: Python (Pandas, Seaborn, Matplotlib)
# By: [Your Name]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\RAVI OJHA\Downloads\Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#calculate % of null values in age column

null_percentage = df['Age'].isnull().mean() * 100
print(f"Percentage of missing values in Age column: {null_percentage:.2f}%")
# Out:
# Percentage of missing values in Age column: 19.87%

# %%
#show null values in heatmap

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis", yticklabels=False)
plt.title("Heatmap of Missing Values")
plt.show()

# %%
#fill null values by median
age_meadian=df["Age"].median()
df["Age"].fillna(age_meadian,inplace=True)
df["Age"]
# Out:
# C:\Users\RAVI OJHA\AppData\Local\Temp\ipykernel_11832\2935789035.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(age_meadian,inplace=True)
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#change age column float to int

df["Age"]=df["Age"].round().astype(int)

# %%
df["Age"].unique()
# Out:
# array([22, 38, 26, 35, 28, 54,  2, 27, 14,  4, 58, 20, 39, 55, 31, 34, 15,
#         8, 19, 40, 66, 42, 21, 18,  3,  7, 49, 29, 65,  5, 11, 45, 17, 32,
#        16, 25,  1, 30, 33, 23, 24, 46, 59, 71, 37, 47, 70, 12,  9, 36, 51,
#        56, 44, 61, 50, 62, 41, 52, 63, 43, 60, 10, 64, 13, 48, 53, 57, 80,
#         6,  0, 74])

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.356902    0.523008
# std     257.353842    0.486592    0.836071   13.017814    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#check duplicate values

df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#how many passenger survives class wise

df[["Survived","Pclass"]].value_counts()
# Out:
# Survived  Pclass
# 0         3         372
# 1         1         136
#           3         119
# 0         2          97
# 1         2          87
# 0         1          80
# Name: count, dtype: int64

# %%
#show class wise survived by stacked plot

crosstab=pd.crosstab(df["Pclass"],df["Survived"])
crosstab.plot(kind="bar",stacked=True,colormap="viridis")
plt.title("Class wise survived")
plt.xlabel("Passenger class")
plt.ylabel("Number of passenger")
plt.legend(title="Survived")
plt.show()

# %%
#male vs female survived


survived = df.groupby(['Sex', 'Survived']).size().unstack()
survived
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
#male vs female survived by stacked chart

plt.figure(figsize=[5,5])
survived.plot(kind="bar",stacked=True,colormap="viridis")
plt.title("Male Vs Female Survived")
plt.xlabel("Sex")
plt.ylabel("number of passenger")
for container in plt.gca().containers:
    plt.bar_label(container)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#how many passenger travles in different class
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#how many passenger in every class

lo=sns.countplot(x="Pclass",data=df)
plt.title("Passenger and his class")
plt.xlabel("Passenger Class")
plt.ylabel("count no of passengers")
for i in lo.containers:
    plt.bar_label(i)
plt.show()

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#What is the gender distribution and survival rate by gender?


plt.figure(figsize=[5,5])
gender=sns.countplot(x="Sex",hue="Survived",data=df)
plt.xlabel("Gender")
plt.ylabel("Survived")
plt.title("Survival by Gender")
for i in gender.containers:
    plt.bar_label(i)
plt.show()

# %%
mo=sns.countplot(x='Embarked', data=df)
plt.title("Number of Passengers by Embarkation Port")
plt.xlabel("Embarked Port")
plt.ylabel("Passenger Count")
for i in mo.containers:
    plt.bar_label(i)
plt.show()

# %%
#survived percentage

df["Survived"].value_counts().plot(kind="pie",autopct="%.2f")
plt.show()

# %%
#Distribution by age

plt.figure(figsize=(8,5))
sns.histplot(df['Age'].dropna(), kde=True, bins=30, color='skyblue')
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
#fare distribution

sns.histplot(df['Fare'], kde=True, bins=40, color='orange')
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()

# %%
#How does passenger class affect survival?

jo=sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival by Passenger Class")
plt.xlabel("Passenger class")
for i in jo.containers:
    plt.bar_label(i)
plt.show()

# %%
#Does age affect survival?

zo=sns.boxplot(x='Survived', y='Age', data=df)
plt.title("Age vs Survival")
plt.show()

# %%
#what are the correlation between numerical variables?


sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Numeric Columns)")
plt.show()

# %%
#show all pariwise relationships

sns.pairplot(df[['Survived', 'Pclass', 'Age', 'Fare']], hue='Survived')

# %%
#survival by embarked port and gender

sns.catplot(x="Embarked", hue="Sex", col="Survived", data=df, kind="count")

# %%
#Box plot for fare column


plt.figure(figsize=(8, 5))
sns.boxplot(x=df['Fare'], color='skyblue')
plt.title("Boxplot of Fare")
plt.xlabel("Fare")
plt.show()

# %%
#Fare vs Pclass 

plt.figure(figsize=(8,5))
sns.boxplot(x='Pclass', y='Fare', data=df, palette='pastel')
plt.title("Fare Distribution across Passenger Classes")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.show()
# Out:
# C:\Users\RAVI OJHA\AppData\Local\Temp\ipykernel_11832\3947566224.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Fare', data=df, palette='pastel')

# %%
#average fare per class
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
#Passenger count per class
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#Average Fare by Class
avg_fare = df.groupby('Pclass')['Fare'].mean().reset_index()

sns.barplot(x='Pclass', y='Fare', data=avg_fare, palette='cool')
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")
plt.show()
# Out:
# C:\Users\RAVI OJHA\AppData\Local\Temp\ipykernel_11832\875456541.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Pclass', y='Fare', data=avg_fare, palette='cool')

# %% [markdown]
# ## ✅ Final Summary of EDA:
#
# - Passengers in 3rd class were the most in number due to low average fare (~₹13), making it affordable.
# - 1st class passengers paid ~₹84 fare on average and had a higher survival rate.
# - Most passengers were aged between 20 and 40 years.
# - Female passengers survived at a much higher rate compared to males.
# - Embarked Port 'S' had the highest number of passengers.
# - Fare and Age had visible outliers, especially among 1st class travelers.
